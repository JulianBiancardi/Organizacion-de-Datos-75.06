# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#EJERCICIO1
#Leemos el archivo y lo guardamos en la variable entrenamiento_ECI

entrenamiento_ECI = pd.read_csv('Entrenamieto_ECI_2020.csv')
entrenamiento_ECI.tail()
# Out:
#           ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 16942   8781      EMEA     Austria                                   1
# 16943   8786      EMEA     Austria                                   1
# 16944   8792      EMEA     Austria                                   1
# 16945  28561  Americas  NE America                                   1
# 16946  28318  Americas  NE America                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 16942                                 1                             1
# 16943                                 1                             1
# 16944                                 1                             1
# 16945                                 1                             1
# 16946                                 1                             1
#
#        Bureaucratic_Code_0_Approved  Submitted_for_Approval  \
# ...

# %%
#EJERCICIO2
#Me quedo con las columnas que me interesan

entrenamiento_ECI_Ejercicio2 = entrenamiento_ECI[['ID', 'Region', 'Territory', 'Delivery_Quarter', 'Delivery_Year', 'Total_Amount']]
entrenamiento_ECI_Ejercicio2.tail()
# Out:
#           ID    Region   Territory Delivery_Quarter  Delivery_Year  \
# 16942   8781      EMEA     Austria               Q1           2016
# 16943   8786      EMEA     Austria               Q2           2016
# 16944   8792      EMEA     Austria               Q1           2016
# 16945  28561  Americas  NE America               Q2           2016
# 16946  28318  Americas  NE America               Q3           2016
#
#        Total_Amount
# 16942     103350.00
# 16943      93015.00
# 16944     103350.00
# 16945    2346796.88
# 16946   25603200.00

# %%
#Quito las filas con NAs
print(len(entrenamiento_ECI_Ejercicio2))
entrenamiento_ECI_Ejercicio2.dropna(inplace = True)
print(len(entrenamiento_ECI_Ejercicio2))
# Out:
# 16947
# 16888
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Me quedo solo con las filas con region EMEA
region_EMEA = entrenamiento_ECI_Ejercicio2['Region'] == 'EMEA'
entrenamiento_ECI_Ejercicio2 = entrenamiento_ECI_Ejercicio2.loc[region_EMEA]
entrenamiento_ECI_Ejercicio2.tail()
# Out:
#           ID Region Territory Delivery_Quarter  Delivery_Year  Total_Amount
# 16938  28767   EMEA   Germany               Q3           2016     1307775.0
# 16939  18324   EMEA    Norway               Q2           2016      401700.0
# 16942   8781   EMEA   Austria               Q1           2016      103350.0
# 16943   8786   EMEA   Austria               Q2           2016       93015.0
# 16944   8792   EMEA   Austria               Q1           2016      103350.0

# %%
#Ordeno las filas de manera descendente miedane el Total_Amount
entrenamiento_ECI_Ejercicio2 = entrenamiento_ECI_Ejercicio2.sort_values(by = ['Total_Amount'], ascending = False)
entrenamiento_ECI_Ejercicio2.head()
# Out:
#          ID Region    Territory Delivery_Quarter  Delivery_Year  Total_Amount
# 2179  10808   EMEA         None               Q2           2016  2.162400e+08
# 3667   8037   EMEA   SE America               Q3           2017  1.539788e+08
# 2806   4909   EMEA  UAE (Dubai)               Q1           2017  1.237501e+08
# 1933  10620   EMEA   Kazakhstan               Q2           2016  3.960007e+07
# 2957  13709   EMEA      Romania               Q2           2016  3.603600e+07

# %%
#Me quedo solo con los 10 primeros
entrenamiento_ECI_Ejercicio2 = entrenamiento_ECI_Ejercicio2[0:10]
entrenamiento_ECI_Ejercicio2 = entrenamiento_ECI_Ejercicio2[['ID', 'Region', 'Delivery_Quarter', 'Delivery_Year']]
entrenamiento_ECI_Ejercicio2
# Out:
#          ID Region Delivery_Quarter  Delivery_Year
# 2179  10808   EMEA               Q2           2016
# 3667   8037   EMEA               Q3           2017
# 2806   4909   EMEA               Q1           2017
# 1933  10620   EMEA               Q2           2016
# 2957  13709   EMEA               Q2           2016
# 598    4865   EMEA               Q4           2017
# 7898  15287   EMEA               Q1           2018
# 1817  10350   EMEA               Q3           2017
# 3684  20848   EMEA               Q4           2016
# 5669  17668   EMEA               Q1           2017

# %%
#EJERCICIO3

territorio_Germany = entrenamiento_ECI['Territory'] == 'Germany'
entrenamiento_ECI_Ejercicio3 = entrenamiento_ECI.loc[territorio_Germany]
entrenamiento_ECI_Ejercicio3.tail()
# Out:
#           ID Region Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 16934  15853   EMEA   Germany                                   0
# 16935  17677   EMEA   Germany                                   0
# 16936  17680   EMEA   Germany                                   0
# 16937  17683   EMEA   Germany                                   0
# 16938  28767   EMEA   Germany                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 16934                                 0                             0
# 16935                                 0                             0
# 16936                                 0                             0
# 16937                                 0                             0
# 16938                                 0                             0
#
#        Bureaucratic_Code_0_Approved  Submitted_for_Approval  \
# 16934                             0                       0
# ...

# %%
#Quito las filas con NAs
entrenamiento_ECI_Ejercicio3.dropna(inplace = True)
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Calculo el promedio de la columna Price

entrenamiento_ECI_Ejercicio3.replace({None: 0})
promedio = entrenamiento_ECI_Ejercicio3['Price'].mean()
print(promedio)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1302         try:
# -> 1303             x = float(x)
#    1304         except ValueError:
#
# ...
